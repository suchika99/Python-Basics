# %% [markdown]
# # Working with Images

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('OpenCV Basics/dog.png')

img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
plt.imshow(img2)
plt.show()
